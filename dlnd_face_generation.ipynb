# %%
import sys, os, platform, inspect

def get_current_file_path():
  # script filename (usually with path)
  filename = inspect.getfile(inspect.currentframe())
  # script directory
  path = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
  return filename, path

if platform.system() == 'Linux' : # Colab setting
  print('Linux')
  from google.colab import drive
  drive.mount('/content/gdrive', force_remount=True)
  path = '/content/gdrive/My Drive/Cours/Udacity_DeepLearning 2019/project-face-generation'
else:
  _, path = get_current_file_path()
  
sys.path.insert(0, path)
os.chdir(path)

# %%
# !ls

# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src="https://docs.google.com/uc?export=download&id=1RB06VoqP6H-83o_ImYepObhXWF95NmYL" width="500">
#
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !pwd

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    
    transform = transforms.Compose([
        transforms.Resize(image_size),
        transforms.CenterCrop(image_size),
        transforms.ToTensor(),
    ])
    dataset = datasets.ImageFolder(data_dir, transform)
    loader = torch.utils.data.DataLoader(dataset= dataset, batch_size = batch_size)
    return loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 24
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max - min) + min
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9765)
# Max:  tensor(0.8745)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
# helper conv function
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """
    creates a convolutional layer with optional batch normalization
    """
    layers = []
    #if group_norm :
    #    layers.append(nn.GroupNorm(in_channels, in_channels))
        
    conv_layer = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    # append conv layer
    layers.append(conv_layer)
    
    if batch_norm :
        layers.append(nn.BatchNorm2d(out_channels))
        
    # using sequential container
    return nn.Sequential(*layers)

class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim

        # 32 x 32 input
        self.conv1 = conv(3, conv_dim, 4, batch_norm = False)
        # 16 x 16 out
        self.conv2 = conv(conv_dim, conv_dim * 2, 4)
        # 8 x 8 out
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4)
        # 4 x 4 out
        
        # final fully connected layer
        self.fc = nn.Linear(conv_dim*4*4*4, 1)
        
        # dropout makes the discriminator
        # less prone to mistakes the generator can exploit instead of learning the data distribution.
        # see : https://github.com/tensorflow/magenta/blob/master/magenta/reviews/GAN.md#disadvantages
        self.dropout = nn.Dropout(0.35)        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        out = F.leaky_relu(self.conv1(x), 0.2)
        out = self.dropout(out)
        out = F.leaky_relu(self.conv2(out), 0.2)
        out = self.dropout(out)
        out = F.leaky_relu(self.conv3(out), 0.2)
        out = self.dropout(out)
        # flatten
        out = out.view(-1, self.conv_dim*4*4*4)
        # final output layer
        out = self.fc(out)
        
        return out       


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
### helper deconv function
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    # create a sequence of transpose + optional batch norm layers
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False) 
    layers.append(transpose_conv_layer)
    if batch_norm :
        #layers.append(nn.BatchNorm2d(out_channels))
        layers.append(nn.GroupNorm(2, out_channels))
    
    return nn.Sequential(*layers)
    
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        # conv_dim = 64
        # first fully connected layer
        self.fc = nn.Linear(z_size, conv_dim * 128) # 64 * 128 = 8192 = 512 * 4 * 4 
        # transpose conv layers
        # 4 x 4 x (depth = 512)
        #self.t_conv0 = deconv(conv_dim * 8, conv_dim * 8, 4, padding=3)
        self.t_conv1 = deconv(conv_dim * 8, conv_dim * 4, 4)
        # 8 x 8 x (depth = 256)
        self.t_conv2 = deconv(conv_dim * 4, conv_dim * 2, 4)
        # 16 x 16 x (depth = 128)
        self.t_conv3 = deconv(conv_dim * 2, conv_dim, 3, stride=1, padding=1)
        # 16 x 16 x (depth = 64)
        self.t_conv4 = deconv(conv_dim, 3, 4, batch_norm=False)
        # 32 x 32 x (depth = 3)

        self.dropout = nn.Dropout(0.35)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        out = self.fc(x)
        out = out.view(-1, self.conv_dim * 8, 4, 4) # depth x width x height
        #out = F.relu(self.t_conv0(out))
        #out = self.dropout(out)
        out = F.relu(self.t_conv1(out))
        out = self.dropout(out)
        out = F.relu(self.t_conv2(out))
        out = self.dropout(out)
        out = F.relu(self.t_conv3(out))
        out = self.dropout(out)
        # last layer + tanh activation
        out = self.t_conv4(out)
        out = torch.tanh(out) 

        return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    if classname.find('Linear') != -1 or classname.find('Conv') != -1 :
        m.weight.data.normal_(0, 0.02)
        if classname.find('Linear') != -1 :
            m.bias.data.fill_(0)    

    # TODO: Apply initial weights to convolutional and linear layers

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 64
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
#   (dropout): Dropout(p=0.35, inplace=False)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=8192, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): GroupNorm(2, 256, eps=1e-05, affine=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): GroupNorm(2, 128, eps=1e-05, affine=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): GroupNorm(2, 64, eps=1e-05, affine=True)
#   )
#   (t_conv4): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (dropout): Dropout(p=0.35, inplace=False)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    # smoothing
    labels = torch.ones(batch_size) * 0.9
    if train_on_gpu :
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    if train_on_gpu :
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def real_mse_loss(D_out):
    target =  np.random.normal(loc=0.95, scale=0.002, size = 1)[0]
    return torch.mean((D_out - target)**2)  # noisy target !!!

def fake_mse_loss(D_out):
    return torch.mean(D_out**2)

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# params
lr = 0.0006  
beta1= 0.27
beta2= 0.999

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
from torch.autograd import Variable

def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)

            #add decaying noise to input - helping generator against discriminator
            alpha = np.exp(-np.sqrt(epoch/(1.5 *n_epochs)))/np.sqrt(epoch + 1)
            noise = Variable(real_images.data.new(real_images.size()).normal_(0.0,0.01))
            real_images += alpha * noise
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            #===============================================
            #         TRAIN THE DISCRIMINATOR
            # ===============================================
            d_optimizer.zero_grad()
            
            # 1. Train the discriminator on real and fake images
            # losses on real images
            
            if train_on_gpu:
                real_images = real_images.cuda()
            D_real = D(real_images)
            d_real_loss = real_mse_loss(D_real)
            
            # losses on fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            D_fake = D(fake_images)
            d_fake_loss = fake_mse_loss(D_fake)
            
            d_loss = d_real_loss + d_fake_loss
            # perform back prop
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            # 2. Train the generator with an adversarial loss
            # generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            # compute the discriminator loss on fake images using flipped labels
            D_fake = D(fake_images)
            g_loss = real_mse_loss(D_fake) # use real loss to flip labels
            # perform back prop
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 20


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   20] | d_loss: 1.2871 | g_loss: 0.9463
# Epoch [    1/   20] | d_loss: 0.7443 | g_loss: 0.8020
# Epoch [    1/   20] | d_loss: 0.3223 | g_loss: 0.9410
# Epoch [    1/   20] | d_loss: 0.4850 | g_loss: 0.2903
# Epoch [    1/   20] | d_loss: 0.6095 | g_loss: 0.6172
# Epoch [    1/   20] | d_loss: 0.6967 | g_loss: 0.3017
# Epoch [    1/   20] | d_loss: 0.6222 | g_loss: 0.2386
# Epoch [    1/   20] | d_loss: 0.5662 | g_loss: 0.9914
# Epoch [    1/   20] | d_loss: 0.5206 | g_loss: 0.8163
# Epoch [    1/   20] | d_loss: 0.4000 | g_loss: 0.3865
# Epoch [    1/   20] | d_loss: 0.3709 | g_loss: 0.4628
# Epoch [    1/   20] | d_loss: 0.4852 | g_loss: 0.4233
# Epoch [    1/   20] | d_loss: 0.4002 | g_loss: 0.2173
# Epoch [    1/   20] | d_loss: 0.4562 | g_loss: 0.6369
# Epoch [    1/   20] | d_loss: 0.4791 | g_loss: 0.9419
# Epoch [    1/   20] | d_loss: 0.4844 | g_loss: 0.2932
# Epoch [    1/   20] | d_loss: 0.4256 | g_loss: 0.3112
# Epoch [    1/   20] | d_loss: 0.4477 | g_loss: 0.4300
# Epoch [    1/   20] | d_loss: 0.3976 | g_loss: 0.8174
# Epoch [    1/   20] | d_loss: 0.3259 | g_loss: 0.3954
# Epoch [    2/   20] | d_loss: 0.6490 | g_loss: 0.8325
# Epoch [    2/   20] | d_loss: 0.5087 | g_loss: 0.3773
# Epoch [    2/   20] | d_loss: 0.5178 | g_loss: 0.3310
# Epoch [    2/   20] | d_loss: 0.5481 | g_loss: 0.7024
# Epoch [    2/   20] | d_loss: 0.5277 | g_loss: 0.4774
# Epoch [    2/   20] | d_loss: 0.4989 | g_loss: 0.2140
# Epoch [    2/   20] | d_loss: 0.3321 | g_loss: 0.7194
# Epoch [    2/   20] | d_loss: 0.4433 | g_loss: 0.3699
# Epoch [    2/   20] | d_loss: 0.4784 | g_loss: 0.3883
# Epoch [    2/   20] | d_loss: 0.5405 | g_loss: 0.3414
# Epoch [    2/   20] | d_loss: 0.5128 | g_loss: 0.1679
# Epoch [    2/   20] | d_loss: 0.4507 | g_loss: 0.3522
# Epoch [    2/   20] | d_loss: 0.4135 | g_loss: 0.4742
# Epoch [    2/   20] | d_loss: 0.3932 | g_loss: 0.4037
# Epoch [    2/   20] | d_loss: 0.3903 | g_loss: 0.4141
# Epoch [    2/   20] | d_loss: 0.4216 | g_loss: 0.2229
# Epoch [    2/   20] | d_loss: 0.5230 | g_loss: 0.5411
# Epoch [    2/   20] | d_loss: 0.4342 | g_loss: 0.2784
# Epoch [    2/   20] | d_loss: 0.5403 | g_loss: 0.1657
# Epoch [    2/   20] | d_loss: 0.4594 | g_loss: 0.3324
# Epoch [    3/   20] | d_loss: 0.4318 | g_loss: 0.5048
# Epoch [    3/   20] | d_loss: 0.4685 | g_loss: 0.3447
# Epoch [    3/   20] | d_loss: 0.4817 | g_loss: 0.3672
# Epoch [    3/   20] | d_loss: 0.4955 | g_loss: 0.4957
# Epoch [    3/   20] | d_loss: 0.3847 | g_loss: 0.4119
# Epoch [    3/   20] | d_loss: 0.5310 | g_loss: 0.2263
# Epoch [    3/   20] | d_loss: 0.5290 | g_loss: 0.3016
# Epoch [    3/   20] | d_loss: 0.3903 | g_loss: 0.4514
# Epoch [    3/   20] | d_loss: 0.3968 | g_loss: 0.6162
# Epoch [    3/   20] | d_loss: 0.5758 | g_loss: 0.4025
# Epoch [    3/   20] | d_loss: 0.3972 | g_loss: 0.4119
# Epoch [    3/   20] | d_loss: 0.4309 | g_loss: 0.1610
# Epoch [    3/   20] | d_loss: 0.4679 | g_loss: 0.3438
# Epoch [    3/   20] | d_loss: 0.4079 | g_loss: 0.2168
# Epoch [    3/   20] | d_loss: 0.4367 | g_loss: 0.3333
# Epoch [    3/   20] | d_loss: 0.5029 | g_loss: 0.3447
# Epoch [    3/   20] | d_loss: 0.4444 | g_loss: 0.5570
# Epoch [    3/   20] | d_loss: 0.4559 | g_loss: 0.1588
# Epoch [    3/   20] | d_loss: 0.3958 | g_loss: 0.2966
# Epoch [    3/   20] | d_loss: 0.4346 | g_loss: 0.4213
# Epoch [    4/   20] | d_loss: 0.5745 | g_loss: 0.2073
# Epoch [    4/   20] | d_loss: 0.4516 | g_loss: 0.2765
# Epoch [    4/   20] | d_loss: 0.4237 | g_loss: 0.3899
# Epoch [    4/   20] | d_loss: 0.4491 | g_loss: 0.1724
# Epoch [    4/   20] | d_loss: 0.4961 | g_loss: 0.4052
# Epoch [    4/   20] | d_loss: 0.4709 | g_loss: 0.3377
# Epoch [    4/   20] | d_loss: 0.4804 | g_loss: 0.4322
# Epoch [    4/   20] | d_loss: 0.4625 | g_loss: 0.3386
# Epoch [    4/   20] | d_loss: 0.4291 | g_loss: 0.5436
# Epoch [    4/   20] | d_loss: 0.5169 | g_loss: 0.4037
# Epoch [    4/   20] | d_loss: 0.4491 | g_loss: 0.2221
# Epoch [    4/   20] | d_loss: 0.5574 | g_loss: 0.3327
# Epoch [    4/   20] | d_loss: 0.3536 | g_loss: 0.3237
# Epoch [    4/   20] | d_loss: 0.4710 | g_loss: 0.3386
# Epoch [    4/   20] | d_loss: 0.4468 | g_loss: 0.3785
# Epoch [    4/   20] | d_loss: 0.4608 | g_loss: 0.3803
# Epoch [    4/   20] | d_loss: 0.4605 | g_loss: 0.2008
# Epoch [    4/   20] | d_loss: 0.4364 | g_loss: 0.3734
# Epoch [    4/   20] | d_loss: 0.3974 | g_loss: 0.3029
# Epoch [    4/   20] | d_loss: 0.4060 | g_loss: 0.3863
# Epoch [    5/   20] | d_loss: 0.4566 | g_loss: 0.5635
# Epoch [    5/   20] | d_loss: 0.4243 | g_loss: 0.2593
# Epoch [    5/   20] | d_loss: 0.4220 | g_loss: 0.3698
# Epoch [    5/   20] | d_loss: 0.5038 | g_loss: 0.2918
# Epoch [    5/   20] | d_loss: 0.4693 | g_loss: 0.3956
# Epoch [    5/   20] | d_loss: 0.4783 | g_loss: 0.2646
# Epoch [    5/   20] | d_loss: 0.4594 | g_loss: 0.3456
# Epoch [    5/   20] | d_loss: 0.3726 | g_loss: 0.2435
# Epoch [    5/   20] | d_loss: 0.4389 | g_loss: 0.4012
# Epoch [    5/   20] | d_loss: 0.5736 | g_loss: 0.3775
# Epoch [    5/   20] | d_loss: 0.4711 | g_loss: 0.3603
# Epoch [    5/   20] | d_loss: 0.4481 | g_loss: 0.3819
# Epoch [    5/   20] | d_loss: 0.4734 | g_loss: 0.3749
# Epoch [    5/   20] | d_loss: 0.4460 | g_loss: 0.4109
# Epoch [    5/   20] | d_loss: 0.3552 | g_loss: 0.4729
# Epoch [    5/   20] | d_loss: 0.4091 | g_loss: 0.3531
# Epoch [    5/   20] | d_loss: 0.4426 | g_loss: 0.2320
# Epoch [    5/   20] | d_loss: 0.3990 | g_loss: 0.2801
# Epoch [    5/   20] | d_loss: 0.4073 | g_loss: 0.2817
# Epoch [    5/   20] | d_loss: 0.5037 | g_loss: 0.2916
# Epoch [    6/   20] | d_loss: 0.4818 | g_loss: 0.3624
# Epoch [    6/   20] | d_loss: 0.5492 | g_loss: 0.3533
# Epoch [    6/   20] | d_loss: 0.4998 | g_loss: 0.4082
# Epoch [    6/   20] | d_loss: 0.4504 | g_loss: 0.3734
# Epoch [    6/   20] | d_loss: 0.3898 | g_loss: 0.2536
# Epoch [    6/   20] | d_loss: 0.4503 | g_loss: 0.3799
# Epoch [    6/   20] | d_loss: 0.4227 | g_loss: 0.2411
# Epoch [    6/   20] | d_loss: 0.4827 | g_loss: 0.3765
# Epoch [    6/   20] | d_loss: 0.5280 | g_loss: 0.2671
# Epoch [    6/   20] | d_loss: 0.4720 | g_loss: 0.3255
# Epoch [    6/   20] | d_loss: 0.4869 | g_loss: 0.2023
# Epoch [    6/   20] | d_loss: 0.4562 | g_loss: 0.2546
# Epoch [    6/   20] | d_loss: 0.4024 | g_loss: 0.3849
# Epoch [    6/   20] | d_loss: 0.5023 | g_loss: 0.3910
# Epoch [    6/   20] | d_loss: 0.4941 | g_loss: 0.2265
# Epoch [    6/   20] | d_loss: 0.3928 | g_loss: 0.2606
# Epoch [    6/   20] | d_loss: 0.5101 | g_loss: 0.2838
# Epoch [    6/   20] | d_loss: 0.4502 | g_loss: 0.3362
# Epoch [    6/   20] | d_loss: 0.4900 | g_loss: 0.3995
# Epoch [    6/   20] | d_loss: 0.3712 | g_loss: 0.2454
# Epoch [    7/   20] | d_loss: 0.4411 | g_loss: 0.3364
# Epoch [    7/   20] | d_loss: 0.4422 | g_loss: 0.2036
# Epoch [    7/   20] | d_loss: 0.4072 | g_loss: 0.3796
# Epoch [    7/   20] | d_loss: 0.4206 | g_loss: 0.2446
# Epoch [    7/   20] | d_loss: 0.4937 | g_loss: 0.4425
# Epoch [    7/   20] | d_loss: 0.4686 | g_loss: 0.2290
# Epoch [    7/   20] | d_loss: 0.4494 | g_loss: 0.2730
# Epoch [    7/   20] | d_loss: 0.4398 | g_loss: 0.4396
# Epoch [    7/   20] | d_loss: 0.4020 | g_loss: 0.3677
# Epoch [    7/   20] | d_loss: 0.5319 | g_loss: 0.2664
# Epoch [    7/   20] | d_loss: 0.4354 | g_loss: 0.2817
# Epoch [    7/   20] | d_loss: 0.4793 | g_loss: 0.1311
# Epoch [    7/   20] | d_loss: 0.4446 | g_loss: 0.3633
# Epoch [    7/   20] | d_loss: 0.4501 | g_loss: 0.3078
# Epoch [    7/   20] | d_loss: 0.4217 | g_loss: 0.3203
# Epoch [    7/   20] | d_loss: 0.4991 | g_loss: 0.3579
# Epoch [    7/   20] | d_loss: 0.3992 | g_loss: 0.3828
# Epoch [    7/   20] | d_loss: 0.4787 | g_loss: 0.3444
# Epoch [    7/   20] | d_loss: 0.4203 | g_loss: 0.2048
# Epoch [    7/   20] | d_loss: 0.4288 | g_loss: 0.2479
# Epoch [    8/   20] | d_loss: 0.4093 | g_loss: 0.3051
# Epoch [    8/   20] | d_loss: 0.4611 | g_loss: 0.3128
# Epoch [    8/   20] | d_loss: 0.4430 | g_loss: 0.2750
# Epoch [    8/   20] | d_loss: 0.4294 | g_loss: 0.2239
# Epoch [    8/   20] | d_loss: 0.4509 | g_loss: 0.3457
# Epoch [    8/   20] | d_loss: 0.4176 | g_loss: 0.3418
# Epoch [    8/   20] | d_loss: 0.4226 | g_loss: 0.2710
# Epoch [    8/   20] | d_loss: 0.4504 | g_loss: 0.2882
# Epoch [    8/   20] | d_loss: 0.4382 | g_loss: 0.3990
# Epoch [    8/   20] | d_loss: 0.4820 | g_loss: 0.1959
# Epoch [    8/   20] | d_loss: 0.5372 | g_loss: 0.3716
# Epoch [    8/   20] | d_loss: 0.4687 | g_loss: 0.2642
# Epoch [    8/   20] | d_loss: 0.4135 | g_loss: 0.3600
# Epoch [    8/   20] | d_loss: 0.3932 | g_loss: 0.3315
# Epoch [    8/   20] | d_loss: 0.4092 | g_loss: 0.3140
# Epoch [    8/   20] | d_loss: 0.4034 | g_loss: 0.2997
# Epoch [    8/   20] | d_loss: 0.4597 | g_loss: 0.4637
# Epoch [    8/   20] | d_loss: 0.4428 | g_loss: 0.2296
# Epoch [    8/   20] | d_loss: 0.4723 | g_loss: 0.3705
# Epoch [    8/   20] | d_loss: 0.4631 | g_loss: 0.2756
# Epoch [    9/   20] | d_loss: 0.3981 | g_loss: 0.1993
# Epoch [    9/   20] | d_loss: 0.4922 | g_loss: 0.2003
# Epoch [    9/   20] | d_loss: 0.4423 | g_loss: 0.2161
# Epoch [    9/   20] | d_loss: 0.3420 | g_loss: 0.2328
# Epoch [    9/   20] | d_loss: 0.5194 | g_loss: 0.5103
# Epoch [    9/   20] | d_loss: 0.4042 | g_loss: 0.2513
# Epoch [    9/   20] | d_loss: 0.4594 | g_loss: 0.3181
# Epoch [    9/   20] | d_loss: 0.4668 | g_loss: 0.3275
# Epoch [    9/   20] | d_loss: 0.4222 | g_loss: 0.2729
# Epoch [    9/   20] | d_loss: 0.4671 | g_loss: 0.2790
# Epoch [    9/   20] | d_loss: 0.3997 | g_loss: 0.3184
# Epoch [    9/   20] | d_loss: 0.4445 | g_loss: 0.2043
# Epoch [    9/   20] | d_loss: 0.3982 | g_loss: 0.4168
# Epoch [    9/   20] | d_loss: 0.4333 | g_loss: 0.3452
# Epoch [    9/   20] | d_loss: 0.5053 | g_loss: 0.4027
# Epoch [    9/   20] | d_loss: 0.4538 | g_loss: 0.3501
# Epoch [    9/   20] | d_loss: 0.4050 | g_loss: 0.3566
# Epoch [    9/   20] | d_loss: 0.5069 | g_loss: 0.2620
# Epoch [    9/   20] | d_loss: 0.4301 | g_loss: 0.3368
# Epoch [    9/   20] | d_loss: 0.4607 | g_loss: 0.2917
# Epoch [   10/   20] | d_loss: 0.4608 | g_loss: 0.3980
# Epoch [   10/   20] | d_loss: 0.3495 | g_loss: 0.2114
# Epoch [   10/   20] | d_loss: 0.4759 | g_loss: 0.4389
# Epoch [   10/   20] | d_loss: 0.4180 | g_loss: 0.2123
# Epoch [   10/   20] | d_loss: 0.4778 | g_loss: 0.2854
# Epoch [   10/   20] | d_loss: 0.4072 | g_loss: 0.2304
# Epoch [   10/   20] | d_loss: 0.4670 | g_loss: 0.2544
# Epoch [   10/   20] | d_loss: 0.3499 | g_loss: 0.3154
# Epoch [   10/   20] | d_loss: 0.4641 | g_loss: 0.3622
# Epoch [   10/   20] | d_loss: 0.5997 | g_loss: 0.2724
# Epoch [   10/   20] | d_loss: 0.4145 | g_loss: 0.3204
# Epoch [   10/   20] | d_loss: 0.4474 | g_loss: 0.3396
# Epoch [   10/   20] | d_loss: 0.4428 | g_loss: 0.4246
# Epoch [   10/   20] | d_loss: 0.4060 | g_loss: 0.3112
# Epoch [   10/   20] | d_loss: 0.4895 | g_loss: 0.3261
# Epoch [   10/   20] | d_loss: 0.4916 | g_loss: 0.3248
# Epoch [   10/   20] | d_loss: 0.3976 | g_loss: 0.3393
# Epoch [   10/   20] | d_loss: 0.4989 | g_loss: 0.3309
# Epoch [   10/   20] | d_loss: 0.3602 | g_loss: 0.3077
# Epoch [   10/   20] | d_loss: 0.4666 | g_loss: 0.3207
# Epoch [   11/   20] | d_loss: 0.4629 | g_loss: 0.3867
# Epoch [   11/   20] | d_loss: 0.3758 | g_loss: 0.2714
# Epoch [   11/   20] | d_loss: 0.4881 | g_loss: 0.3193
# Epoch [   11/   20] | d_loss: 0.3787 | g_loss: 0.3110
# Epoch [   11/   20] | d_loss: 0.4172 | g_loss: 0.3191
# Epoch [   11/   20] | d_loss: 0.4362 | g_loss: 0.2840
# Epoch [   11/   20] | d_loss: 0.3772 | g_loss: 0.3395
# Epoch [   11/   20] | d_loss: 0.3552 | g_loss: 0.2632
# Epoch [   11/   20] | d_loss: 0.4236 | g_loss: 0.3062
# Epoch [   11/   20] | d_loss: 0.5034 | g_loss: 0.3511
# Epoch [   11/   20] | d_loss: 0.5408 | g_loss: 0.2653
# Epoch [   11/   20] | d_loss: 0.4226 | g_loss: 0.3293
# Epoch [   11/   20] | d_loss: 0.3988 | g_loss: 0.3586
# Epoch [   11/   20] | d_loss: 0.3544 | g_loss: 0.3028
# Epoch [   11/   20] | d_loss: 0.4706 | g_loss: 0.3423
# Epoch [   11/   20] | d_loss: 0.3845 | g_loss: 0.1849
# Epoch [   11/   20] | d_loss: 0.4223 | g_loss: 0.3586
# Epoch [   11/   20] | d_loss: 0.4366 | g_loss: 0.2974
# Epoch [   11/   20] | d_loss: 0.4588 | g_loss: 0.3229
# Epoch [   11/   20] | d_loss: 0.4269 | g_loss: 0.3132
# Epoch [   12/   20] | d_loss: 0.3232 | g_loss: 0.2536
# Epoch [   12/   20] | d_loss: 0.3779 | g_loss: 0.3841
# Epoch [   12/   20] | d_loss: 0.4354 | g_loss: 0.3381
# Epoch [   12/   20] | d_loss: 0.4280 | g_loss: 0.2582
# Epoch [   12/   20] | d_loss: 0.4232 | g_loss: 0.3948
# Epoch [   12/   20] | d_loss: 0.4107 | g_loss: 0.3180
# Epoch [   12/   20] | d_loss: 0.5100 | g_loss: 0.3130
# Epoch [   12/   20] | d_loss: 0.3688 | g_loss: 0.4836
# Epoch [   12/   20] | d_loss: 0.4342 | g_loss: 0.4251
# Epoch [   12/   20] | d_loss: 0.4587 | g_loss: 0.3168
# Epoch [   12/   20] | d_loss: 0.4839 | g_loss: 0.2655
# Epoch [   12/   20] | d_loss: 0.4508 | g_loss: 0.1915
# Epoch [   12/   20] | d_loss: 0.3807 | g_loss: 0.4244
# Epoch [   12/   20] | d_loss: 0.3815 | g_loss: 0.2254
# Epoch [   12/   20] | d_loss: 0.4839 | g_loss: 0.2301
# Epoch [   12/   20] | d_loss: 0.4351 | g_loss: 0.2400
# Epoch [   12/   20] | d_loss: 0.3688 | g_loss: 0.3704
# Epoch [   12/   20] | d_loss: 0.5402 | g_loss: 0.1910
# Epoch [   12/   20] | d_loss: 0.5045 | g_loss: 0.3145
# Epoch [   12/   20] | d_loss: 0.4128 | g_loss: 0.2848
# Epoch [   13/   20] | d_loss: 0.3650 | g_loss: 0.2263
# Epoch [   13/   20] | d_loss: 0.4970 | g_loss: 0.3984
# Epoch [   13/   20] | d_loss: 0.4283 | g_loss: 0.3317
# Epoch [   13/   20] | d_loss: 0.3544 | g_loss: 0.3994
# Epoch [   13/   20] | d_loss: 0.4817 | g_loss: 0.3553
# Epoch [   13/   20] | d_loss: 0.4930 | g_loss: 0.3039
# Epoch [   13/   20] | d_loss: 0.4216 | g_loss: 0.3373
# Epoch [   13/   20] | d_loss: 0.3957 | g_loss: 0.3680
# Epoch [   13/   20] | d_loss: 0.4325 | g_loss: 0.4236
# Epoch [   13/   20] | d_loss: 0.4500 | g_loss: 0.4006
# Epoch [   13/   20] | d_loss: 0.4418 | g_loss: 0.2472
# Epoch [   13/   20] | d_loss: 0.4997 | g_loss: 0.2912
# Epoch [   13/   20] | d_loss: 0.4138 | g_loss: 0.3505
# Epoch [   13/   20] | d_loss: 0.3655 | g_loss: 0.4077
# Epoch [   13/   20] | d_loss: 0.4105 | g_loss: 0.3563
# Epoch [   13/   20] | d_loss: 0.4809 | g_loss: 0.3116
# Epoch [   13/   20] | d_loss: 0.3163 | g_loss: 0.3927
# Epoch [   13/   20] | d_loss: 0.4702 | g_loss: 0.3804
# Epoch [   13/   20] | d_loss: 0.3993 | g_loss: 0.3118
# Epoch [   13/   20] | d_loss: 0.4296 | g_loss: 0.2965
# Epoch [   14/   20] | d_loss: 0.3568 | g_loss: 0.3075
# Epoch [   14/   20] | d_loss: 0.3508 | g_loss: 0.3712
# Epoch [   14/   20] | d_loss: 0.3996 | g_loss: 0.3439
# Epoch [   14/   20] | d_loss: 0.4949 | g_loss: 0.3021
# Epoch [   14/   20] | d_loss: 0.4747 | g_loss: 0.3899
# Epoch [   14/   20] | d_loss: 0.4279 | g_loss: 0.4432
# Epoch [   14/   20] | d_loss: 0.4243 | g_loss: 0.2717
# Epoch [   14/   20] | d_loss: 0.4664 | g_loss: 0.2018
# Epoch [   14/   20] | d_loss: 0.3343 | g_loss: 0.2829
# Epoch [   14/   20] | d_loss: 0.4294 | g_loss: 0.3163
# Epoch [   14/   20] | d_loss: 0.4063 | g_loss: 0.2749
# Epoch [   14/   20] | d_loss: 0.3942 | g_loss: 0.2878
# Epoch [   14/   20] | d_loss: 0.3446 | g_loss: 0.2590
# Epoch [   14/   20] | d_loss: 0.4239 | g_loss: 0.3641
# Epoch [   14/   20] | d_loss: 0.3337 | g_loss: 0.2724
# Epoch [   14/   20] | d_loss: 0.4554 | g_loss: 0.2503
# Epoch [   14/   20] | d_loss: 0.3090 | g_loss: 0.3217
# Epoch [   14/   20] | d_loss: 0.4111 | g_loss: 0.4550
# Epoch [   14/   20] | d_loss: 0.3831 | g_loss: 0.3448
# Epoch [   14/   20] | d_loss: 0.4055 | g_loss: 0.3008
# Epoch [   15/   20] | d_loss: 0.4215 | g_loss: 0.4081
# Epoch [   15/   20] | d_loss: 0.3624 | g_loss: 0.2322
# Epoch [   15/   20] | d_loss: 0.3827 | g_loss: 0.3617
# Epoch [   15/   20] | d_loss: 0.4314 | g_loss: 0.3819
# Epoch [   15/   20] | d_loss: 0.4536 | g_loss: 0.4633
# Epoch [   15/   20] | d_loss: 0.4008 | g_loss: 0.3152
# Epoch [   15/   20] | d_loss: 0.4241 | g_loss: 0.3478
# Epoch [   15/   20] | d_loss: 0.2526 | g_loss: 0.3054
# Epoch [   15/   20] | d_loss: 0.4165 | g_loss: 0.3270
# Epoch [   15/   20] | d_loss: 0.4492 | g_loss: 0.2774
# Epoch [   15/   20] | d_loss: 0.4109 | g_loss: 0.3300
# Epoch [   15/   20] | d_loss: 0.4666 | g_loss: 0.1990
# Epoch [   15/   20] | d_loss: 0.3128 | g_loss: 0.4052
# Epoch [   15/   20] | d_loss: 0.3783 | g_loss: 0.4987
# Epoch [   15/   20] | d_loss: 0.3994 | g_loss: 0.3310
# Epoch [   15/   20] | d_loss: 0.4213 | g_loss: 0.2553
# Epoch [   15/   20] | d_loss: 0.3903 | g_loss: 0.4094
# Epoch [   15/   20] | d_loss: 0.3565 | g_loss: 0.3724
# Epoch [   15/   20] | d_loss: 0.3197 | g_loss: 0.2533
# Epoch [   15/   20] | d_loss: 0.3549 | g_loss: 0.4355
# Epoch [   16/   20] | d_loss: 0.4353 | g_loss: 0.2879
# Epoch [   16/   20] | d_loss: 0.3647 | g_loss: 0.3191
# Epoch [   16/   20] | d_loss: 0.4445 | g_loss: 0.2321
# Epoch [   16/   20] | d_loss: 0.5201 | g_loss: 0.3277
# Epoch [   16/   20] | d_loss: 0.3718 | g_loss: 0.2533
# Epoch [   16/   20] | d_loss: 0.3905 | g_loss: 0.4080
# Epoch [   16/   20] | d_loss: 0.3405 | g_loss: 0.3606
# Epoch [   16/   20] | d_loss: 0.3993 | g_loss: 0.4395
# Epoch [   16/   20] | d_loss: 0.4257 | g_loss: 0.4211
# Epoch [   16/   20] | d_loss: 0.5282 | g_loss: 0.2587
# Epoch [   16/   20] | d_loss: 0.4619 | g_loss: 0.1779
# Epoch [   16/   20] | d_loss: 0.4709 | g_loss: 0.2419
# Epoch [   16/   20] | d_loss: 0.3807 | g_loss: 0.4070
# Epoch [   16/   20] | d_loss: 0.4268 | g_loss: 0.3399
# Epoch [   16/   20] | d_loss: 0.4133 | g_loss: 0.4627
# Epoch [   16/   20] | d_loss: 0.3300 | g_loss: 0.4266
# Epoch [   16/   20] | d_loss: 0.4102 | g_loss: 0.4314
# Epoch [   16/   20] | d_loss: 0.3175 | g_loss: 0.3287
# Epoch [   16/   20] | d_loss: 0.4293 | g_loss: 0.6303
# Epoch [   16/   20] | d_loss: 0.4092 | g_loss: 0.2925
# Epoch [   17/   20] | d_loss: 0.4191 | g_loss: 0.3747
# Epoch [   17/   20] | d_loss: 0.4253 | g_loss: 0.5502
# Epoch [   17/   20] | d_loss: 0.3664 | g_loss: 0.3685
# Epoch [   17/   20] | d_loss: 0.4339 | g_loss: 0.2931
# Epoch [   17/   20] | d_loss: 0.4617 | g_loss: 0.5818
# Epoch [   17/   20] | d_loss: 0.5590 | g_loss: 0.3822
# Epoch [   17/   20] | d_loss: 0.4394 | g_loss: 0.3790
# Epoch [   17/   20] | d_loss: 0.3994 | g_loss: 0.3176
# Epoch [   17/   20] | d_loss: 0.4670 | g_loss: 0.2963
# Epoch [   17/   20] | d_loss: 0.4175 | g_loss: 0.2556
# Epoch [   17/   20] | d_loss: 0.3518 | g_loss: 0.2653
# Epoch [   17/   20] | d_loss: 0.4239 | g_loss: 0.2784
# Epoch [   17/   20] | d_loss: 0.2996 | g_loss: 0.4224
# Epoch [   17/   20] | d_loss: 0.3115 | g_loss: 0.3519
# Epoch [   17/   20] | d_loss: 0.3316 | g_loss: 0.3971
# Epoch [   17/   20] | d_loss: 0.4458 | g_loss: 0.2504
# Epoch [   17/   20] | d_loss: 0.2734 | g_loss: 0.3637
# Epoch [   17/   20] | d_loss: 0.3381 | g_loss: 0.3767
# Epoch [   17/   20] | d_loss: 0.3321 | g_loss: 0.3023
# Epoch [   17/   20] | d_loss: 0.3918 | g_loss: 0.2434
# Epoch [   18/   20] | d_loss: 0.3527 | g_loss: 0.4604
# Epoch [   18/   20] | d_loss: 0.4567 | g_loss: 0.1816
# Epoch [   18/   20] | d_loss: 0.5415 | g_loss: 0.2939
# Epoch [   18/   20] | d_loss: 0.3457 | g_loss: 0.5500
# Epoch [   18/   20] | d_loss: 0.4095 | g_loss: 0.3973
# Epoch [   18/   20] | d_loss: 0.4106 | g_loss: 0.3121
# Epoch [   18/   20] | d_loss: 0.2848 | g_loss: 0.2660
# Epoch [   18/   20] | d_loss: 0.3435 | g_loss: 0.3205
# Epoch [   18/   20] | d_loss: 0.3595 | g_loss: 0.3609
# Epoch [   18/   20] | d_loss: 0.3885 | g_loss: 0.3341
# Epoch [   18/   20] | d_loss: 0.3355 | g_loss: 0.3981
# Epoch [   18/   20] | d_loss: 0.3678 | g_loss: 0.3187
# Epoch [   18/   20] | d_loss: 0.3653 | g_loss: 0.4408
# Epoch [   18/   20] | d_loss: 0.3809 | g_loss: 0.2227
# Epoch [   18/   20] | d_loss: 0.4303 | g_loss: 0.2901
# Epoch [   18/   20] | d_loss: 0.3648 | g_loss: 0.3490
# Epoch [   18/   20] | d_loss: 0.3580 | g_loss: 0.4858
# Epoch [   18/   20] | d_loss: 0.3662 | g_loss: 0.2967
# Epoch [   18/   20] | d_loss: 0.4299 | g_loss: 0.4162
# Epoch [   18/   20] | d_loss: 0.3810 | g_loss: 0.4414
# Epoch [   19/   20] | d_loss: 0.2882 | g_loss: 0.4146
# Epoch [   19/   20] | d_loss: 0.4245 | g_loss: 0.2587
# Epoch [   19/   20] | d_loss: 0.3515 | g_loss: 0.4472
# Epoch [   19/   20] | d_loss: 0.2702 | g_loss: 0.2364
# Epoch [   19/   20] | d_loss: 0.4131 | g_loss: 0.3155
# Epoch [   19/   20] | d_loss: 0.3171 | g_loss: 0.3637
# Epoch [   19/   20] | d_loss: 0.3738 | g_loss: 0.3743
# Epoch [   19/   20] | d_loss: 0.3407 | g_loss: 0.3703
# Epoch [   19/   20] | d_loss: 0.3466 | g_loss: 0.3572
# Epoch [   19/   20] | d_loss: 0.4826 | g_loss: 0.4800
# Epoch [   19/   20] | d_loss: 0.3371 | g_loss: 0.4778
# Epoch [   19/   20] | d_loss: 0.3759 | g_loss: 0.3589
# Epoch [   19/   20] | d_loss: 0.3207 | g_loss: 0.4881
# Epoch [   19/   20] | d_loss: 0.3586 | g_loss: 0.3748
# Epoch [   19/   20] | d_loss: 0.5003 | g_loss: 0.4657
# Epoch [   19/   20] | d_loss: 0.3940 | g_loss: 0.2753
# Epoch [   19/   20] | d_loss: 0.3113 | g_loss: 0.2952
# Epoch [   19/   20] | d_loss: 0.4641 | g_loss: 0.3961
# Epoch [   19/   20] | d_loss: 0.3475 | g_loss: 0.2836
# Epoch [   19/   20] | d_loss: 0.4113 | g_loss: 0.3763
# Epoch [   20/   20] | d_loss: 0.3795 | g_loss: 0.3304
# Epoch [   20/   20] | d_loss: 0.3834 | g_loss: 0.4078
# Epoch [   20/   20] | d_loss: 0.4070 | g_loss: 0.2319
# Epoch [   20/   20] | d_loss: 0.3728 | g_loss: 0.3319
# Epoch [   20/   20] | d_loss: 0.3400 | g_loss: 0.4325
# Epoch [   20/   20] | d_loss: 0.4045 | g_loss: 0.5184
# Epoch [   20/   20] | d_loss: 0.4103 | g_loss: 0.4252
# Epoch [   20/   20] | d_loss: 0.3703 | g_loss: 0.3807
# Epoch [   20/   20] | d_loss: 0.4092 | g_loss: 0.4097
# Epoch [   20/   20] | d_loss: 0.3494 | g_loss: 0.4006
# Epoch [   20/   20] | d_loss: 0.4544 | g_loss: 0.2290
# Epoch [   20/   20] | d_loss: 0.3848 | g_loss: 0.3419
# Epoch [   20/   20] | d_loss: 0.3229 | g_loss: 0.5000
# Epoch [   20/   20] | d_loss: 0.3278 | g_loss: 0.4004
# Epoch [   20/   20] | d_loss: 0.3801 | g_loss: 0.3398
# Epoch [   20/   20] | d_loss: 0.3785 | g_loss: 0.3619
# Epoch [   20/   20] | d_loss: 0.2486 | g_loss: 0.4029
# Epoch [   20/   20] | d_loss: 0.3918 | g_loss: 0.4472
# Epoch [   20/   20] | d_loss: 0.4205 | g_loss: 0.4235
# Epoch [   20/   20] | d_loss: 0.4410 | g_loss: 0.3474

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
# >- The dataset is biased : the input faces are mostly white and thus the DCGAN generates faces that are mostly white.
# >- The generator network has 4 layers and a conv dim = 64 (= last depth before outputting images) : so the results have rather good colors; it was not the case in previous experiments with conv dim  = 32. An additional 5th layer could help in detecting features (hair, eyes, ...)  but it would also take more time to train and I am not sure it is worth it since the input images do not have a limited resolution (32x32 pixels)
# >- For optmization strategy, I followed some recommendations in <https://github.com/soumith/ganhacks>, namely :
#   - added noise to labels (see function real_mse_loss)
#   - added decaying noise to input images
#   - used dropout in dicriminator and generator

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
